# %% [markdown]
# <a href="https://colab.research.google.com/github/waggomes/Projetos_python/blob/master/Aula_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

fonte = 'https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true'

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
dados.shape
# Out:
# (127380, 136)

# %%
dados['SG_UF_RESIDENCIA']
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
dados[['SG_UF_RESIDENCIA','Q025']]
# Out:
#        SG_UF_RESIDENCIA Q025
# 0                    PA    B
# 1                    PA    B
# 2                    PA    B
# 3                    PA    B
# 4                    PA    B
# ...                 ...  ...
# 127375               MG    B
# 127376               BA    B
# 127377               BA    B
# 127378               BA    A
# 127379               MG    B
#
# [127380 rows x 2 columns]

# %%
dados['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
len(dados['SG_UF_RESIDENCIA'].unique())
# Out:
# 27

# %%
dados['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados['NU_IDADE'].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados['NU_IDADE'].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %% [markdown]
# Desafio 01: Analisar a representatividade por idade.
#
# Desafio 02: Descobrir de quais estados são os inscritos com 13 anos.

# %%
#Desafio 01

dados['NU_IDADE'].value_counts(normalize = True)
# Out:
# 18    0.168409
# 17    0.166871
# 19    0.113189
# 20    0.081748
# 16    0.061470
#         ...
# 75    0.000016
# 73    0.000016
# 82    0.000008
# 77    0.000008
# 76    0.000008
# Name: NU_IDADE, Length: 65, dtype: float64

# %%
#Desafio 02

dados.query('NU_IDADE == 13')[['NU_IDADE','SG_UF_RESIDENCIA']]
# Out:
#         NU_IDADE SG_UF_RESIDENCIA
# 57359         13               SP
# 95630         13               MT
# 98197         13               AP
# 116501        13               BA

# %%
dados['NU_IDADE'].hist()

# %%
grafico1 = dados['NU_IDADE'].hist(bins = 20, figsize = (10, 8))

# %% [markdown]
# Desafio 03: Colocar titulos no gráfico acima.

# %%
dados.query("IN_TREINEIRO == 1")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# 12      190001005076    2019                  1506138  ...    A     A    B
# 14      190001005081    2019                  1506807  ...    A     A    B
# 16      190001005202    2019                  1502301  ...    A     A    A
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127328  190006117441    2019                  3126752  ...    A     A    B
# 127340  190006117776    2019                  4305108  ...    A     C    B
# 127349  190006118483    2019                  2511301  ...    A     A    A
# 127350  190006118551    2019                  2611606  ...    B     B    B
# 127352  190006118561    2019                  2600807  ...    A     A    B
#
# [15401 rows x 136 columns]

# %%
dados.query("IN_TREINEIRO == 1")['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %% [markdown]
# Desafio 04: Plotar o histograma das idades dos trineiros e não treineiros.

# %%
dados['NU_NOTA_REDACAO'].hist(bins = 20, figsize = (8, 6))

# %%
dados['NU_NOTA_LC'].hist(bins = 20, figsize = (8, 6))

# %%
dados['NU_NOTA_REDACAO'].mean()
# Out:
# 571.5700253970197

# %%
dados['NU_NOTA_REDACAO'].std()
# Out:
# 188.07645455749753

# %%
provas = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_MT','NU_NOTA_LC','NU_NOTA_REDACAO']

dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
dados['NU_NOTA_REDACAO'].quantile(0.9)
# Out:
# 800.0

# %%
dados['NU_NOTA_REDACAO'].plot.box(grid = True, figsize = (8, 6))

# %%
dados[provas].plot.box(grid = True, figsize = (10, 6))

# %% [markdown]
# Desafio 05: Plotar as distribuições das provas em Ingles e espanhol

# %%
dados.query('NU_IDADE <= 14')['SG_UF_RESIDENCIA'].value_counts(normalize = True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# SP    0.075862
# MG    0.075862
# MA    0.062069
# PI    0.048276
# GO    0.048276
# PB    0.048276
# DF    0.027586
# MT    0.027586
# AM    0.027586
# SE    0.020690
# TO    0.020690
# PR    0.020690
# AL    0.013793
# SC    0.013793
# RO    0.013793
# RS    0.006897
# RJ    0.006897
# AC    0.006897
# AP    0.006897
# MS    0.006897
# ES    0.006897
# RN    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
alunos_menor_quatorze = dados.query('NU_IDADE <= 14')
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts().plot.pie(figsize = (10, 10))

# %%
alunos_menor_quatorze['SG_UF_RESIDENCIA'].value_counts().plot.bar(figsize = (10, 10))

# %%
dados['TP_SEXO'].value_counts(normalize = True).plot.pie(figsize = (10, 8))

# %%
len(alunos_menor_quatorze)
# Out:
# 145

# %%
alunos_menor_quatorze['Q006'].value_counts(normalize = True)
# Out:
# C    0.144828
# E    0.117241
# D    0.103448
# B    0.096552
# F    0.075862
# Q    0.062069
# H    0.055172
# L    0.048276
# J    0.048276
# P    0.048276
# N    0.048276
# A    0.041379
# G    0.034483
# K    0.027586
# M    0.027586
# I    0.020690
# Name: Q006, dtype: float64

# %%
dados['Q006'].value_counts().plot.bar()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.title('Boxplot')
sns.boxplot(x = 'Q006',y = 'NU_NOTA_MT', data = dados)

# %%
renda_ordenada = dados['Q006'].unique()
renda_ordenada.sort()

# %%
plt.figure(figsize = (10, 10))
plt.title('Boxplot')
sns.boxplot(x = 'Q006',y = 'NU_NOTA_MT', data = dados, order = renda_ordenada)

# %%
provas = ['NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_CN',
       'NU_NOTA_REDACAO']

# %%
dados[provas].sum()
# Out:
# NU_NOTA_CH         49743676.1
# NU_NOTA_LC         51027844.9
# NU_NOTA_MT         48563933.8
# NU_NOTA_CN         44334986.1
# NU_NOTA_REDACAO    56038440.0
# dtype: float64

# %%
dados[provas].sum(axis = 1)
# Out:
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#            ...
# 127375    2867.4
# 127376    2218.5
# 127377    1453.9
# 127378    2573.9
# 127379    2287.8
# Length: 127380, dtype: float64

# %%
dados['NU_NOTA_TOTAL'] = dados[provas].sum(axis = 1)

# %%
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize = (20, 10))
plt.title('Boxplot')
sns.boxplot(x = 'Q006',y = 'NU_NOTA_TOTAL', data = dados, order = renda_ordenada)

# %%
sns.displot(dados, x = 'NU_NOTA_TOTAL', kde = True)

# %%
dados.query('NU_NOTA_TOTAL == 0')
# Out:
#         NU_INSCRICAO  NU_ANO  ...  Q025 NU_NOTA_TOTAL
# 10      190001005028    2019  ...     A           0.0
# 11      190001005057    2019  ...     B           0.0
# 26      190001005484    2019  ...     B           0.0
# 38      190001006086    2019  ...     B           0.0
# 40      190001006292    2019  ...     B           0.0
# ...              ...     ...  ...   ...           ...
# 127351  190006118552    2019  ...     B           0.0
# 127365  190006119756    2019  ...     A           0.0
# 127366  190006119783    2019  ...     A           0.0
# 127368  190006119802    2019  ...     B           0.0
# 127374  190006119995    2019  ...     B           0.0
#
# [29162 rows x 137 columns]

# %%
provas = ['NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_CN',
       'NU_NOTA_REDACAO']
provas.append('NU_NOTA_TOTAL')
provas.append('Q006')
provas.append('Q025')
provas.append('IN_TREINEIRO')
dados[provas].query('NU_NOTA_TOTAL == 0')
# Out:
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  ...  Q006  Q025  IN_TREINEIRO
# 10             NaN         NaN         NaN  ...     B     A             0
# 11             NaN         NaN         NaN  ...     B     B             0
# 26             NaN         NaN         NaN  ...     C     B             0
# 38             NaN         NaN         NaN  ...     C     B             0
# 40             NaN         NaN         NaN  ...     G     B             0
# ...            ...         ...         ...  ...   ...   ...           ...
# 127351         NaN         NaN         NaN  ...     H     B             0
# 127365         NaN         NaN         NaN  ...     C     A             0
# 127366         NaN         NaN         NaN  ...     B     A             0
# 127368         NaN         NaN         NaN  ...     C     B             0
# 127374         NaN         NaN         NaN  ...     C     B             0
#
# [29162 rows x 9 columns]

# %% [markdown]
# Desafio 03 : Criar uma função para plotar os dados do seaborn
#
# Desafio 04 : verificar se quem zeour a prova foi eliminado ou não estava presente
#
# Desafio 05 : quem é eliminado tem nota 0 ou NaN
#
# Desafio 06 : verificar a proporção dos participantes de rendas mais altase mais baixas como treineiros
#
# Desafio 07 : fazer um boxplot considerando a questão 25 (internet sim/não)

# %%
dados_sem_notas_zero = dados[provas].query('NU_NOTA_TOTAL != 0')
dados_sem_notas_zero.head()
# Out:
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  ...  Q006  Q025  IN_TREINEIRO
# 0       512.3       488.6       432.4  ...     B     B             1
# 1       409.3       375.3         NaN  ...     B     B             0
# 2       499.1       441.0       427.2  ...     C     B             0
# 3       578.1       551.5       499.9  ...     B     B             0
# 4       571.3       511.2       424.5  ...     E     B             1
#
# [5 rows x 9 columns]

# %%
plt.figure(figsize = (15, 8))
plt.title('Boxplot')
sns.boxplot(x = 'Q006',y = 'NU_NOTA_TOTAL', data = dados_sem_notas_zero, order = renda_ordenada)

# %%
plt.figure(figsize = (15, 8))
plt.title('Boxplot')
sns.boxplot(x = 'Q006',y = 'NU_NOTA_TOTAL', data = dados_sem_notas_zero, order = renda_ordenada, hue = 'IN_TREINEIRO')

# %%
def plotar(str):
  plt.figure(figsize = (15, 8))
  plt.title('Boxplot')
  sns.boxplot(x = 'Q006',y = 'NU_NOTA_TOTAL', data = dados_sem_notas_zero, order = renda_ordenada)
  pass

# %% [markdown]
# *****************AULA 3*******************************

# %%
plt.figure(figsize = (10, 10))
sns.histplot(dados_sem_notas_zero, x = 'NU_NOTA_TOTAL')

# %% [markdown]
# Desafio 01 : Plotar as médias, medianas e moda nas notas de LC e MT

# %%
plt.figure(figsize = (15, 8))
plt.title('Boxplot')
sns.boxplot(x = 'Q025',y = 'NU_NOTA_TOTAL', data = dados_sem_notas_zero, order = renda_ordenada)

# %%
plt.figure(figsize = (10, 10))
sns.histplot(dados_sem_notas_zero, x = 'NU_NOTA_TOTAL', hue = 'Q025', kde = True, cumulative = True)

# %%
plt.figure(figsize = (10, 10))
sns.histplot(dados_sem_notas_zero, x = 'NU_NOTA_TOTAL', hue = 'Q025', kde = True, stat = 'probability')

# %%
plt.figure(figsize = (10, 10))
sns.scatterplot(data = dados_sem_notas_zero, x = 'NU_NOTA_MT', y = 'NU_NOTA_LC')
plt.xlim((50, 1050))
plt.ylim((50, 1050))
# Out:
# (50.0, 1050.0)

# %%
sns.pairplot(dados_sem_notas_zero[provas])

# %%
correlacao = dados_sem_notas_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CH  NU_NOTA_LC  ...  NU_NOTA_TOTAL  IN_TREINEIRO
# NU_NOTA_CH         1.000000    0.744170  ...       0.735534      0.017890
# NU_NOTA_LC         0.744170    1.000000  ...       0.711686      0.027112
# NU_NOTA_MT         0.610332    0.587710  ...       0.790051      0.055999
# NU_NOTA_CN         0.668979    0.641624  ...       0.785600      0.028518
# NU_NOTA_REDACAO    0.528338    0.535797  ...       0.783647      0.000163
# NU_NOTA_TOTAL      0.735534    0.711686  ...       1.000000      0.010288
# IN_TREINEIRO       0.017890    0.027112  ...       0.010288      1.000000
#
# [7 rows x 7 columns]

# %%
sns.heatmap(correlacao, cmap = "Blues", center = 0, annot = True)

# %% [markdown]
# *************AULA 4******************************

# %%
provas_entrada = ['NU_NOTA_LC', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_REDACAO']
prova_saida = 'NU_NOTA_MT'

dados_sem_notas_zero = dados_sem_notas_zero[provas].dropna()

notas_entrada = dados_sem_notas_zero[provas_entrada]
notas_saida = dados_sem_notas_zero[prova_saida]
notas_entrada
# Out:
#         NU_NOTA_LC  NU_NOTA_CH  NU_NOTA_CN  NU_NOTA_REDACAO
# 0            488.6       512.3       435.6            420.0
# 2            441.0       499.1       423.2            560.0
# 3            551.5       578.1       426.2            500.0
# 4            511.2       571.3       516.5            780.0
# 5            607.5       618.7       559.6            900.0
# ...            ...         ...         ...              ...
# 127373       485.3       501.5       480.4            520.0
# 127375       525.7       559.6       502.4            740.0
# 127376       450.3       380.9       449.1            520.0
# 127378       517.3       416.2       564.7            620.0
# 127379       477.1       425.5       466.7            480.0
#
# [92537 rows x 4 columns]

# %%
x = notas_entrada
y = notas_saida

# %%
from sklearn.model_selection import train_test_split
seed = 4321
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state = seed )

# %%
x_treino.head()
# Out:
#         NU_NOTA_LC  NU_NOTA_CH  NU_NOTA_CN  NU_NOTA_REDACAO
# 90200        523.2       567.7       542.7            660.0
# 12375        423.0       497.1       445.2            580.0
# 46320        528.5       494.0       454.0            520.0
# 111208       572.7       561.9       385.8            640.0
# 75943        646.5       686.5       625.7            900.0

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state=seed)
modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=4321, tol=0.0001, verbose=0)

# %%
predicoes_matematica = modelo.predict(x_teste)

# %%
sns.scatterplot(x = predicoes_matematica, y = y_teste)
plt.figure(figsize=(10,10))
plt.xlim = (0, 1000)
plt.ylim = (0, 1000)

# %%
sns.scatterplot(x = y_teste, y = y_teste - predicoes_matematica)

# %%
resultados = pd.DataFrame()
resultados['Real'] = y_teste
resultados['Previsão'] = predicoes_matematica
resultados['Diferença'] = resultados['Real'] - resultados['Previsão']
resultados['quadrado_diferença'] = (resultados['Real'] - resultados['Previsão'])**2

# %%
resultados
# Out:
#          Real    Previsão   Diferença  quadrado_diferença
# 114991  459.7  564.486105 -104.786105        10980.127878
# 104685  617.2  628.305027  -11.105027          123.321625
# 91028   520.0  509.980986   10.019014          100.380650
# 115802  703.8  593.681144  110.118856        12126.162420
# 93303   627.1  579.784588   47.315412         2238.748252
# ...       ...         ...         ...                 ...
# 81393   688.6  626.291851   62.308149         3882.305380
# 40159   479.1  652.313922 -173.213922        30003.062777
# 64083   501.4  607.787172 -106.387172        11318.230438
# 84661   772.5  734.227663   38.272337         1464.771772
# 79106   369.0  466.919690  -97.919690         9588.265665
#
# [23135 rows x 4 columns]

# %%
resultados['quadrado_diferença'].mean()
# Out:
# 6604.41530621952

# %%
resultados['quadrado_diferença'].mean()**(1/2)
# Out:
# 81.26755383435335

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino, y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12063.645588509502

# %%
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 6604.415306219557

# %% [markdown]
# Desafio 01 : encontrar outro modelo e aplicar e verificar o erro

# %% [markdown]
# *****************AULA 05***********************

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = seed)
modelo.fit(x_treino, y_treino)
predicoes_matematica = modelo.predict(x_teste)
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 6604.415306219557

# %%
from sklearn.tree import DecisionTreeRegressor
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state = seed )
modelo_arvore = DecisionTreeRegressor(max_depth=3)
modelo_arvore.fit(x_treino, y_treino)
predicoes_matematica_arvore = modelo_arvore.predict(x_teste)

# %%
mean_squared_error(y_teste, predicoes_matematica_arvore)
# Out:
# 6027.166905272973
